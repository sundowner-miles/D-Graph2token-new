# %%
pip install modelscope

# %%
from modelscope import snapshot_download

# 修改这里：加上 "LLM-Research/" 前缀
model_dir = snapshot_download('LLM-Research/Meta-Llama-3-8B')

print(f"模型下载路径: {model_dir}")
# Out:
# Downloading Model from https://www.modelscope.cn to directory: /home/cheung-in-Yonsei/.cache/modelscope/hub/models/LLM-Research/Meta-Llama-3-8B
# 模型下载路径: /home/cheung-in-Yonsei/.cache/modelscope/hub/models/LLM-Research/Meta-Llama-3-8B
